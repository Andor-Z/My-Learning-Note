# %%
# %run -i  c3.py

# %%
print(getwordcounts('http://blog.outer-court.com/rss.xml'))
# Out:
# ('Google Blogoscoped', {<built-in method lower of str object at 0x0000000000E4DB90>: 1, <built-in method lower of str object at 0x0000000000E47AB0>: 1, <built-in method lower of str object at 0x0000000000E63C38>: 1, <built-in method lower of str object at 0x0000000000E54420>: 1, <built-in method lower of str object at 0x0000000000E601F0>: 1, <built-in method lower of str object at 0x0000000000E47F10>: 1, <built-in method lower of str object at 0x0000000000E63618>: 1, <built-in method lower of str object at 0x0000000000E51768>: 1, <built-in method lower of str object at 0x0000000000E24D50>: 1, <built-in method lower of str object at 0x0000000000E4D298>: 1, <built-in method lower of str object at 0x0000000000E54C00>: 1, <built-in method lower of str object at 0x0000000000E49030>: 1, <built-in method lower of str object at 0x0000000000E470D8>: 1, <built-in method lower of str object at 0x0000000000E46378>: 1, <built-in method lower of str object at 0x0000000000E56148>: 1, <built-in meth
# ...
